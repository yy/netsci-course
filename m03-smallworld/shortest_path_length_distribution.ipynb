# %% [markdown]
# # Assignment
#
# For this assignment you will calculate and plot the distribution of the path lengths of a graph. First we will generate a random graph which we will use for the assignment.

# %%
# Please use this random seed for submission.
import random
random.seed(42)        
import numpy as np
np.random.seed(42)

# %%
import networkx as nx

random_graph = nx.erdos_renyi_graph(1200, 0.008, seed=42)
print(nx.info(random_graph))

# %% [markdown]
# ## 1. Finding path lengths
#
# You can use Networkx's [shortest path length function](https://networkx.github.io/documentation/stable/reference/algorithms/generated/networkx.algorithms.shortest_paths.generic.shortest_path_length.html#networkx.algorithms.shortest_paths.generic.shortest_path_length) to get the shortest path between nodes in a graph. (You can also challenge yourself more by creating your own shortest path function). Try out some of the examples in the documentation using the random graph we made above until you get familiar with how it works and what type of output it gives.
#
# **Q1**: Next write a function that will return a **sorted** list of the shortest path lengths between all pairs of nodes (make sure each pair is only counted once). It should sort by the path length, not the nodes.
#
# This function should take a single argument, `G`, a networkx graph. The return type should be a list of ints, i.e. something like: `[1,1,2,3,4,...]`

# %%
def sorted_shortest_path_lengths(G):
    # your code here
    pass

# %% [markdown]
# Apply your function to the ```random_graph``` and assign the list of shortest path lengths to a variable:

# %%
s = nx.shortest_path_length(random_graph)

# %%
for n in random_graph.nodes():
    s = nx.shortest_path_length(random_graph, target = n)
    print(s)

# %% [markdown]
# ## 2. Visualizing the results
# Now that you have a list of the shortest paths for the graph, make a histogram for it. This can be done with [matplotlibs histogram function](http://matplotlib.org/api/pyplot_api.html?highlight=hist#matplotlib.pyplot.hist)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# This function is fairly useful and lets us quickly visualize a distribution. For instance, if we create a small set of normally distributed random numbers we could use the histogram function to plot the bell curve:

# %%
import numpy as np
# Create dummy data
rvs = np.random.normal(size=1000)
# plot histogram
pdf, bins, patch = plt.hist(rvs, bins=30)

# %% [markdown]
# You may need to adjust the number of bins so that it is appropriate for the amount of data points you have.
#
# **Q2: Use the histogram function to make a plot of the results from your shortest paths length function**

# %%
# code here

# %% [markdown]
# ### Name your notebook: shortest_lastname_firstname.ipynb and submit to Canvas
